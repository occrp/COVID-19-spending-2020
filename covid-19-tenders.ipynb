# %% [markdown]
# # OCCRP’s COVID-19 Procurement Explorer
# *OCCRP and media partners collected data on COVID-19 related spending from across Europe from February to October this year.
# The story analyzing the data can be found [here](https://www.occrp.org/en/coronavirus/europes-covid-19-spending-spree-unmasked).*
#
# *We have also decided to share the raw data with the public.*

# %% [markdown]
# In this notebook, we will clean the data for analysis and explain some of the features and caveats of the data along the way. We have collected data into **two data sets**: tenders and contracts, and unit prices.
#
#
# ## Source data sets
#
# ### 1. TENDERS
#
# This dataset contains information on contracts and tenders related to COVID-19. This information can be found [here](https://docs.google.com/spreadsheets/d/1VXURZlKH-_GeNvPrytgJOeTUH3hXf0r_veIXWJp1K20/edit?usp=sharing).
# A quick note here on the difference between contracts and tenders. Where as contracts typically cover a simple, one-off purchase from a single company, tenders are often divided into multiple parts, or “lots”, with more than one company acting as supplier.
# This means there is sometimes duplication in this data. The data is structured around companies (i.e. one row = one winning company). If a tender has multiple winning companies, that means it spans over multiple rows.
#
# We have also made an effort to categorize each tender or contract (visible in the `product` column), in order to filter out those not related to COVID-19, and to make it easier to compare different deals with each other. This process was done with a mix of manual edits and automation, meaning that there may be mistakes.
#
#
# ### 2. UNIT PRICES
#
# This dataset contains information on the prices paid per unit for certain COVID-19 purchases. The information can also be found in the [Unit Prices Sheet](https://docs.google.com/spreadsheets/d/10VL5FpviSXctagcoQM_pr0xP4Lsmzzc3-i7mEyCE2kw/edit?usp=sharing).
# This data comes from multiple sources. In Ukraine, for example, data came from the [Prozorro](https://prozorro.gov.ua/en/tender/search/) procurement platform. In Portugal, data was obtained from the government and filtered and categorized by our media partner [Publico](https://www.publico.pt). Czech data was filtered by [hlidacstatu.cz](https://www.hlidacstatu.cz/).
# Most of the time there is a reference to a source and an ID corresponding to the relevant tender or contract.
#
#
# # Data frames
# In this notebook, we are pulling in the raw data, cleaning it and creating three data frames for you to explore:
#
#
# 1. **TENDERS** : Contains information on tenders and contracts for COVID-19 related services and equipment on the tender/contract level. Contains information on price, date, descriptions, and buyers (NOT companies).
#
# 2. **COMPANIES** :  Contains information on the companies that have sold COVID-19 related services and equipment. Information includes company details, price, date, descriptions, and buyers.
#
# 3. **UNIT_PRICES** : Contains information on the unit prices of a particular COVID-19 related equipment.
#
#
# ## A note on working with tender data
#
# Tender data is notoriously difficult to work with. The most common caveats are:
#
# * The data is **incomplete** in many ways. Most of the countries don't publish all of their expenses. In some countries (e.g. Portugal, Spain, Czechia, Russia, UK) nearly all contracts are openly published. In others (e.g. Germany, France, the Netherlands) only the largest, so called EU-level tenders are published. The largest tenders account for only about ~1/3 of total expenditures. Even if a tender is published, some of the information is often missing. It's not unusual to see for example the price either missing, or even set to zero or one euro.
#
# * The **company names are not standardized**. Governments can fill in company names in many ways and so make it very difficult to calculate how much a particular company is making from tenders in general.
#
#
# Part of this repository is a collection of cleaning scripts called `covidtenders`. `pandas` is used for the rest.

# %%
import pandas as pd

import covidtenders
from importlib import reload
reload(covidtenders)

pd.set_option("max_colwidth", 500)
pd.set_option("max_rows", 100)
pd.set_option("max_columns", 50)
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('mode.chained_assignment', None)

import warnings
warnings.filterwarnings("ignore")

# %%
# load the whole TENDERS data set
alldata = pd.read_csv("source_tables/alldata.csv")

# Cleaning the TENDERS for TENDERS (see `covidtenders.py` for details on the steps)
#TENDERS = covidtenders.filter_just_tenders(alldata)

# Cleaning the for the COMPANIES (see `covidtenders.py` for details on the steps)
COMPANIES = covidtenders.filter_just_companies(alldata,
                                               missing_prices_filled_in_dataset = "source_tables/companies_prices_missing_filled_in.csv",
                                               companies_deduped = "source_tables/companies_deduped.csv")

# Loading and cleaning UNIT PRICES (see `covidtenders.py` for details on the steps)
#UNIT_PRICES = pd.read_csv("source_tables/unit_prices.csv")
#UNIT_PRICES = covidtenders.clean_unitprices(UNIT_PRICES)

TENDERS.to_csv("exports/occrp-covid19-tenders.csv", index=False)
COMPANIES.to_csv("exports/companies_final.csv", index=False)
UNIT_PRICES.to_csv("exports/unit-prices-clean.csv", index=False)
# Out:
# +++ Cleaning TENDER data for COMPANY details +++
# ORIGINAL size: 56461 rows
# ... after cleaning: 41341 rows
# -----------
# Step 1: contracts + single win tenders from + single win lots from + unique tenders = 39255 winning bids
#               date      product            type  \
# ID
# AT0004  2020-04-06  Ventilators  awarded tender
# AT0005  2020-03-16  Ventilators  awarded tender
# AT0006  2020-03-16  Ventilators  awarded tender
# AT0007  2020-03-16  Ventilators  awarded tender
# AT0008  2020-03-13  Ventilators  awarded tender
#
#                                   title  lot buyer_country  \
# ID
# AT0004  COVID-Beatmungsgeräte & Zubehör  NaN            AT
# AT0005                  Beatmungsgeräte  NaN            AT
# AT0006                  Beatmungsgeräte  NaN            AT
# AT0007  COVID-Beatmungsgeräte & Zubehör  NaN            AT
# AT0008  Covid-Beatmungsgeräte & Zubehör  NaN            AT
#
#                         supplier  price_contract_EUR  price_EUR  \
# ID
# AT0004    Heinen+Löwenstein GmbH          437,020.80 437,020.80
# AT0005  Heinen & Löwenstein GmbH          758,416.00 758,416.00
# AT0006  Heinen & Löwenstein GmbH          461,706.00 461,706.00
# AT0007   Getinge Österreich GmbH          250,000.00 250,000.00
# AT0008       Dräger Austria GmbH          306,242.32 306,242.32
#
#         price_lot_EUR supplier_id supplier_country supplier_city  \
# ID
# AT0004     437,020.80         NaN               AT          2500
# AT0005     758,416.00         NaN               AT          2500
# AT0006     461,706.00         NaN               AT          2500
# AT0007     250,000.00         NaN               AT          1230
# AT0008     306,242.32         NaN               AT          1230
#
#        supplier_street supplier_postcode     procedure bids  \
# ID
# AT0004             NaN               NaN  direct award 1.00
# AT0005             NaN               NaN  direct award 1.00
# AT0006             NaN               NaN  direct award 1.00
# AT0007             NaN               NaN  direct award 1.00
# AT0008             NaN               NaN  direct award 1.00
#
#            contract_number             TED_id      price price_currency  \
# ID
# AT0004                 NaN  2020/S 073-174150   437020.8            EUR
# AT0005  TDZ/T03-K01-313542  2020/S 071-168642   758416.0            EUR
# AT0006  TDZ/T03-K02-313415  2020/S 071-168640   461706.0            EUR
# AT0007                 NaN  2020/S 067-159096   250000.0            EUR
# AT0008                 NaN  2020/S 057-135741  306242.32            EUR
#
#         price_lot  \
# ID
# AT0004   437020.8
# AT0005   758416.0
# AT0006   461706.0
# AT0007   250000.0
# AT0008  306242.32
#
#                                                                   source  \
# ID
# AT0004  http://ted.europa.eu/udl?uri=TED:NOTICE:174150-2020:TEXT:DE:HTML
# AT0005  http://ted.europa.eu/udl?uri=TED:NOTICE:168642-2020:TEXT:DE:HTML
# AT0006  http://ted.europa.eu/udl?uri=TED:NOTICE:168640-2020:TEXT:DE:HTML
# AT0007  http://ted.europa.eu/udl?uri=TED:NOTICE:159096-2020:TEXT:DE:HTML
# AT0008  http://ted.europa.eu/udl?uri=TED:NOTICE:135741-2020:TEXT:DE:HTML
#
#                   supplier_clean
# ID
# AT0004    Heinen+Löwenstein GmbH
# AT0005  Heinen & Löwenstein GmbH
# AT0006  Heinen & Löwenstein GmbH
# AT0007   Getinge Österreich GmbH
# AT0008       Dräger Austria GmbH
# Step 2: manually deduplicated 14218 company names
# -----------
# Returning: 35846 rows
# Missing: 2104 winning bids

# %% [markdown]
# ## TENDERS
#
# **Biggest spenders** :
# In the UK, tender data is open by default. Germany only publishes in TED.

# %%
TENDERS.groupby("buyer_country")["price_EUR"].sum().reset_index().nlargest(15,"price_EUR").style.bar()
# (EC = European Commission)
# Out:
# <style  type="text/css" >
#     #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.2%, transparent 8.2%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.1%, transparent 7.1%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.2%, transparent 6.2%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.7%, transparent 3.7%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_682ad8dc_1371_11eb_8754_672ffeec1eacrow14_col1 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_682ad8dc_1371_11eb_8754_672ffeec1eac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >buyer_country</th>        <th class="col_heading level0 col1" >price_EUR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row0" class="row_heading level0 row0" >37</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow0_col0" class="data row0 col0" >UK</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow0_col1" class="data row0 col1" >10030816670.970715</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row1" class="row_heading level0 row1" >10</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow1_col0" class="data row1 col0" >EC</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow1_col1" class="data row1 col1" >3465894674.290000</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row2" class="row_heading level0 row2" >8</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow2_col0" class="data row2 col0" >DE</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow2_col1" class="data row2 col1" >2081221755.359999</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row3" class="row_heading level0 row3" >20</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow3_col0" class="data row3 col0" >IT</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow3_col1" class="data row3 col1" >904554970.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row4" class="row_heading level0 row4" >12</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow4_col0" class="data row4 col0" >ES</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow4_col1" class="data row4 col1" >800985771.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row5" class="row_heading level0 row5" >1</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow5_col0" class="data row5 col0" >AT</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow5_col1" class="data row5 col1" >706154997.001950</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row6" class="row_heading level0 row6" >32</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow6_col0" class="data row6 col0" >RU</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow6_col1" class="data row6 col1" >676598513.852159</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row7" class="row_heading level0 row7" >30</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow7_col0" class="data row7 col0" >PT</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow7_col1" class="data row7 col1" >463817905.663480</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row8" class="row_heading level0 row8" >14</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow8_col0" class="data row8 col0" >FR</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow8_col1" class="data row8 col1" >286789780.890000</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row9" class="row_heading level0 row9" >11</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow9_col0" class="data row9 col0" >EE</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow9_col1" class="data row9 col1" >245059046.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row10" class="row_heading level0 row10" >7</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow10_col0" class="data row10 col0" >CZ</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow10_col1" class="data row10 col1" >224242952.602449</td>
#             </tr>
#             <tr>
#                         <th id="T_682ad8dc_1371_11eb_8754_672ffeec1eaclevel0_row11" class="row_heading level0 row11" >3</th>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow11_col0" class="data row11 col0" >BE</td>
#                         <td id="T_682ad8dc_1371_11eb_8754_672ffeec1eacrow11_col1" class="data row11 col1" >165021551.990000</td>
#             </tr>
#             <tr>

# %% [markdown]
# **Biggest publishers of tenders** : Portugal is our best data set. Portugal publishes all contracts on a designated website and the data collection was regurarly updated, cleaned and categorized by our partner [Publico](https://www.publico.pt/). Portugeese data have therefore the potential to be used as a base line for how the pandemic spending looked like. Lithuania is another case where the data was regurarly collected, cleaned and published directly by the government publication office (but we did not succeed in categorizing them all).

# %%
TENDERS.groupby("buyer_country")["product"].count().reset_index().nlargest(15,"product").style.bar()
# Out:
# <style  type="text/css" >
#     #T_682fe552_1371_11eb_8754_672ffeec1eacrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 81.1%, transparent 81.1%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.0%, transparent 14.0%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.9%, transparent 9.9%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.2%, transparent 7.2%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 3.3%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.2%, transparent 3.2%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.7%, transparent 2.7%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 1.4%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_682fe552_1371_11eb_8754_672ffeec1eacrow14_col1 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_682fe552_1371_11eb_8754_672ffeec1eac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >buyer_country</th>        <th class="col_heading level0 col1" >product</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row0" class="row_heading level0 row0" >30</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow0_col0" class="data row0 col0" >PT</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow0_col1" class="data row0 col1" >15217</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row1" class="row_heading level0 row1" >32</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow1_col0" class="data row1 col0" >RU</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow1_col1" class="data row1 col1" >12364</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row2" class="row_heading level0 row2" >36</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow2_col0" class="data row2 col0" >UA</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow2_col1" class="data row2 col1" >2229</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row3" class="row_heading level0 row3" >31</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow3_col0" class="data row3 col0" >RO</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow3_col1" class="data row3 col1" >1615</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row4" class="row_heading level0 row4" >24</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow4_col0" class="data row4 col0" >MD</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow4_col1" class="data row4 col1" >1208</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row5" class="row_heading level0 row5" >7</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow5_col0" class="data row5 col0" >CZ</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow5_col1" class="data row5 col1" >979</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row6" class="row_heading level0 row6" >37</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow6_col0" class="data row6 col0" >UK</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow6_col1" class="data row6 col1" >616</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row7" class="row_heading level0 row7" >21</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow7_col0" class="data row7 col0" >LT</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow7_col1" class="data row7 col1" >606</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row8" class="row_heading level0 row8" >1</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow8_col0" class="data row8 col0" >AT</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow8_col1" class="data row8 col1" >536</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row9" class="row_heading level0 row9" >12</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow9_col0" class="data row9 col0" >ES</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow9_col1" class="data row9 col1" >329</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row10" class="row_heading level0 row10" >14</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow10_col0" class="data row10 col0" >FR</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow10_col1" class="data row10 col1" >259</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row11" class="row_heading level0 row11" >8</th>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow11_col0" class="data row11 col0" >DE</td>
#                         <td id="T_682fe552_1371_11eb_8754_672ffeec1eacrow11_col1" class="data row11 col1" >257</td>
#             </tr>
#             <tr>
#                         <th id="T_682fe552_1371_11eb_8754_672ffeec1eaclevel0_row12" class="row_heading level0 row12" >34</th>
#                         <td id="

# %% [markdown]
# ## COMPANIES
# The **50 largest suppliers**

# %%
COMPANIES.groupby("supplier_clean")["price_contract_EUR"].sum().reset_index().nlargest(50, "price_contract_EUR").style.bar()
# Out:
# <style  type="text/css" >
#     #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.3%, transparent 32.3%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.2%, transparent 24.2%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.0%, transparent 21.0%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.3%, transparent 18.3%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.3%, transparent 17.3%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.4%, transparent 15.4%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.4%, transparent 14.4%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.2%, transparent 13.2%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.7%, transparent 12.7%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.7%, transparent 12.7%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.7%, transparent 11.7%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.1%, transparent 9.1%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.0%, transparent 9.0%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.8%, transparent 8.8%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.2%, transparent 8.2%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.4%, transparent 7.4%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.4%, transparent 7.4%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.2%, transparent 7.2%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.2%, transparent 7.2%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.5%, transparent 6.5%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.0%, transparent 6.0%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.8%, transparent 5.8%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.6%, transparent 5.6%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.5%, transparent 5.5%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.1%, transparent 5.1%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.1%, transparent 5.1%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.8%, transparent 3.8%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.2%, transparent 3.2%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.8%, transparent 2.8%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.7%, transparent 2.7%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow36_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow37_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow38_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffeec1eacrow39_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#         }    #T_683ae6e6_1371_11eb_8754_672ffee

# %% [markdown]
# **!!!** We also encountered cases of some tenders **duplicated in the source data** (e.g. the TED database), see an example here [[1]](https://ted.europa.eu/udl?uri=TED:NOTICE:240431-2020:TEXT:EN:HTML) [[2]](https://ted.europa.eu/udl?uri=TED:NOTICE:288971-2020:TEXT:EN:HTML). We **did not clean** these. See example below.

# %%
COMPANIES[COMPANIES["supplier"] == "Müller und Meirer Lederwaren"]

# uncomment below to see more possible duplicates
# companies[(companies.duplicated(["title","price_contract_EUR", "supplier"]))].sort_values("price_contract_EUR", ascending=False)
# Out:
#             date                     product            type  \
# 1779  2020-04-23  PPE (protective equipment)  awarded tender
# 1780  2020-04-23  PPE (protective equipment)  awarded tender
#
#                                                                             title  \
# 1779  20-00155_01, Beschaffung von Einweghandschuhen aufgrund der Corona-Epidemie
# 1780  20-00155_01, Beschaffung von Einweghandschuhen aufgrund der Corona-Epidemie
#
#      lot buyer_country                      supplier  price_contract_EUR  \
# 1779   1            DE  Müller und Meirer Lederwaren       15,750,000.00
# 1780   1            DE  Müller und Meirer Lederwaren       15,750,000.00
#
#          price_EUR  price_lot_EUR supplier_id supplier_country supplier_city  \
# 1779 15,750,000.00  15,750,000.00         NaN               DE           Kim
# 1780 15,750,000.00  15,750,000.00         NaN               DE          Kirn
#
#      supplier_street supplier_postcode     procedure bids contract_number  \
# 1779      Am Markt 8             55606  direct award 1.00     20-00155_01
# 1780      Am Markt 8             55606  direct award 1.00     20-00155_01
#
#                  TED_id       price price_currency   price_lot  \
# 1779  2020/S 100-240431  15750000.0            EUR  15750000.0
# 1780  2020/S 119-288971  15750000.0            EUR  15750000.0
#
#                                                                 source  \
# 1779  http://ted.europa.eu/udl?uri=TED:NOTICE:240431-2020:TEXT:DE:HTML
# 1780  http://ted.europa.eu/udl?uri=TED:NOTICE:288971-2020:TEXT:DE:HTML
#
#                     supplier_clean  diff
# 1779  müller und meirer lederwaren  0.35
# 1780  müller und meirer lederwaren  0.35

# %% [markdown]
# ### UNIT_PRICES
# Most frequent countries of origin

# %%
UNIT_PRICES["country"].value_counts().reset_index().style.bar()
# Out:
# <style  type="text/css" >
#     #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.8%, transparent 40.8%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.4%, transparent 25.4%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.1%, transparent 19.1%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.3%, transparent 14.3%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.8%, transparent 7.8%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.5%, transparent 4.5%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.1%, transparent 4.1%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.8%, transparent 3.8%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.0%, transparent 3.0%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow19_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_684e3cc8_1371_11eb_8754_672ffeec1eacrow20_col1 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_684e3cc8_1371_11eb_8754_672ffeec1eac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >country</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow0_col0" class="data row0 col0" >Ukraine</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow0_col1" class="data row0 col1" >3731</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow1_col0" class="data row1 col0" >Portugal</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow1_col1" class="data row1 col1" >1523</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow2_col0" class="data row2 col0" >Moldova</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow2_col1" class="data row2 col1" >1265</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow3_col0" class="data row3 col0" >Lithuania</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow3_col1" class="data row3 col1" >948</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow4_col0" class="data row4 col0" >Czechia</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow4_col1" class="data row4 col1" >714</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow5_col0" class="data row5 col0" >Sweden</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow5_col1" class="data row5 col1" >537</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow6_col0" class="data row6 col0" >Austria</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow6_col1" class="data row6 col1" >294</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow7_col0" class="data row7 col0" >Spain</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow7_col1" class="data row7 col1" >169</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow8_col0" class="data row8 col0" >Greece</td>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffeec1eacrow8_col1" class="data row8 col1" >155</td>
#             </tr>
#             <tr>
#                         <th id="T_684e3cc8_1371_11eb_8754_672ffeec1eaclevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_684e3cc8_1371_11eb_8754_672ffee

# %% [markdown]
# The most *often occuring* category are **medical gloves** (these might not be comparable because of different types of gloves)

# %%
UNIT_PRICES["Product category"].value_counts().reset_index().head(10).style.bar()
# Out:
# <style  type="text/css" >
#     #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 57.7%, transparent 57.7%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.5%, transparent 11.5%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.4%, transparent 7.4%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.2%, transparent 6.2%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.7%, transparent 5.7%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.4%, transparent 3.4%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }    #T_6852b9e2_1371_11eb_8754_672ffeec1eacrow9_col1 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_6852b9e2_1371_11eb_8754_672ffeec1eac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Product category</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow0_col0" class="data row0 col0" >MEDICAL GLOVES</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow0_col1" class="data row0 col1" >2046</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow1_col0" class="data row1 col0" >FFP2</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow1_col1" class="data row1 col1" >1278</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow2_col0" class="data row2 col0" >OTHER MEDICAL EQUIPMENT</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow2_col1" class="data row2 col1" >438</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow3_col0" class="data row3 col0" >MASK (UNSPECIFIED)</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow3_col1" class="data row3 col1" >364</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow4_col0" class="data row4 col0" >OTHER: NON MEDICAL</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow4_col1" class="data row4 col1" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow5_col0" class="data row5 col0" >DISPOSABLE COVERALL</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow5_col1" class="data row5 col1" >333</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow6_col0" class="data row6 col0" >MEDICINES AND OTHER PILLS</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow6_col1" class="data row6 col1" >291</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow7_col0" class="data row7 col0" >VENTILATORS</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow7_col1" class="data row7 col1" >249</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow8_col0" class="data row8 col0" >DISINFECTANTS</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow8_col1" class="data row8 col1" >246</td>
#             </tr>
#             <tr>
#                         <th id="T_6852b9e2_1371_11eb_8754_672ffeec1eaclevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow9_col0" class="data row9 col0" >SURGICAL MASK</td>
#                         <td id="T_6852b9e2_1371_11eb_8754_672ffeec1eacrow9_col1" class="data row9 col1" >229</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The items bought in *largest amounts* were **surgical masks**. These most probably refer to the disposable 3-ply masks.

# %%
UNIT_PRICES.groupby("Product category")["amount"].sum().reset_index().nlargest(10,"amount").style.bar()
# Out:
# <style  type="text/css" >
#     #T_6858abfe_1371_11eb_8754_672ffeec1eacrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.9%, transparent 67.9%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 53.1%, transparent 53.1%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.8%, transparent 11.8%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.2%, transparent 11.2%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.2%, transparent 6.2%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 3.3%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_6858abfe_1371_11eb_8754_672ffeec1eacrow9_col1 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_6858abfe_1371_11eb_8754_672ffeec1eac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Product category</th>        <th class="col_heading level0 col1" >amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row0" class="row_heading level0 row0" >49</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow0_col0" class="data row0 col0" >SURGICAL MASK</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow0_col1" class="data row0 col1" >671134258.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row1" class="row_heading level0 row1" >15</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow1_col0" class="data row1 col0" >FFP2</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow1_col1" class="data row1 col1" >460785542.625966</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row2" class="row_heading level0 row2" >34</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow2_col0" class="data row2 col0" >MEDICAL GLOVES</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow2_col1" class="data row2 col1" >363459170.632414</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row3" class="row_heading level0 row3" >27</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow3_col0" class="data row3 col0" >KN95</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow3_col1" class="data row3 col1" >92358193.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row4" class="row_heading level0 row4" >36</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow4_col0" class="data row4 col0" >N95</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow4_col1" class="data row4 col1" >88529585.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row5" class="row_heading level0 row5" >33</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow5_col0" class="data row5 col0" >MASK TYPE II</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow5_col1" class="data row5 col1" >55666542.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row6" class="row_heading level0 row6" >38</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow6_col0" class="data row6 col0" >OTHER MEDICAL EQUIPMENT</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow6_col1" class="data row6 col1" >36386202.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row7" class="row_heading level0 row7" >16</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow7_col0" class="data row7 col0" >FFP3</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow7_col1" class="data row7 col1" >22254634.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row8" class="row_heading level0 row8" >31</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow8_col0" class="data row8 col0" >MASK (UNSPECIFIED)</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow8_col1" class="data row8 col1" >16394699.398197</td>
#             </tr>
#             <tr>
#                         <th id="T_6858abfe_1371_11eb_8754_672ffeec1eaclevel0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow9_col0" class="data row9 col0" >DISPOSABLE COVERALL</td>
#                         <td id="T_6858abfe_1371_11eb_8754_672ffeec1eacrow9_col1" class="data row9 col1" >14841353.100000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# However, the *most money* was spent on **FFP2 and equivalent - (K)N95 respirators**. As these is a standardized item, the prices are comparable cross-border

# %%
UNIT_PRICES.groupby("Product category")["spent"].sum().reset_index().nlargest(10,"spent").style.bar()
# Out:
# <style  type="text/css" >
#     #T_685bde64_1371_11eb_8754_672ffeec1eacrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.0%, transparent 14.0%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.9%, transparent 6.9%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.6%, transparent 5.6%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.9%, transparent 4.9%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_685bde64_1371_11eb_8754_672ffeec1eacrow9_col1 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_685bde64_1371_11eb_8754_672ffeec1eac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Product category</th>        <th class="col_heading level0 col1" >spent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow0_col0" class="data row0 col0" >FFP2</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow0_col1" class="data row0 col1" >1571087041.695052</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row1" class="row_heading level0 row1" >49</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow1_col0" class="data row1 col0" >SURGICAL MASK</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow1_col1" class="data row1 col1" >267498957.265798</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row2" class="row_heading level0 row2" >27</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow2_col0" class="data row2 col0" >KN95</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow2_col1" class="data row2 col1" >160183274.485131</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row3" class="row_heading level0 row3" >36</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow3_col0" class="data row3 col0" >N95</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow3_col1" class="data row3 col1" >139517236.190000</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row4" class="row_heading level0 row4" >10</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow4_col0" class="data row4 col0" >DISPOSABLE COVERALL</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow4_col1" class="data row4 col1" >129733130.224320</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row5" class="row_heading level0 row5" >16</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow5_col0" class="data row5 col0" >FFP3</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow5_col1" class="data row5 col1" >108829255.889650</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row6" class="row_heading level0 row6" >53</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow6_col0" class="data row6 col0" >VENTILATOR</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow6_col1" class="data row6 col1" >88195305.130943</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row7" class="row_heading level0 row7" >6</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow7_col0" class="data row7 col0" >COVID19 TEST KIT</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow7_col1" class="data row7 col1" >59172731.068550</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row8" class="row_heading level0 row8" >5</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow8_col0" class="data row8 col0" >COVID19 TEST</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow8_col1" class="data row8 col1" >58803113.552679</td>
#             </tr>
#             <tr>
#                         <th id="T_685bde64_1371_11eb_8754_672ffeec1eaclevel0_row9" class="row_heading level0 row9" >38</th>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow9_col0" class="data row9 col0" >OTHER MEDICAL EQUIPMENT</td>
#                         <td id="T_685bde64_1371_11eb_8754_672ffeec1eacrow9_col1" class="data row9 col1" >55355381.392337</td>
#             </tr>
#     </tbody></table>
